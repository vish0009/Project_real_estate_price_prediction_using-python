# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as plt

# %%
real_estate = pd.read_csv('data/real_estate.csv')

real_estate.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
# area_type       13320 non-null object
# availability    13320 non-null object
# location        13319 non-null object
# size            13304 non-null object
# society         7818 non-null object
# total_sqft      13320 non-null object
# bath            13247 non-null float64
# balcony         12711 non-null float64
# price           13320 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 936.6+ KB

# %%
real_estate.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
real_estate.shape
# Out:
# (13320, 9)

# %% [markdown]
# # After Checking DataSet...Start Cleaning.....

# %% [markdown]
# #"area_type" column cleaning

# %%
real_estate["area_type"].nunique() #4 types
real_estate["area_type"].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.scatter(real_estate['price'], real_estate['area_type'])
plt.show()
real_estate["area_type"].value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
# on average plot Area and Super build-up Area seems to have more influance on price then others 
# they need higher weights

# we give approx weights 1,2,3,4
real_estate['area_type']=real_estate['area_type'].map({'Carpet  Area': 1, 'Plot  Area': 3, 'Built-up  Area': 2, 'Super built-up  Area': 4})

real_estate.head()
# Out:
#    area_type   availability                  location       size  society  \
# 0          4         19-Dec  Electronic City Phase II      2 BHK  Coomee
# 1          3  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp
# 2          2  Ready To Move               Uttarahalli      3 BHK      NaN
# 3          4  Ready To Move        Lingadheeranahalli      3 BHK  Soiewre
# 4          4  Ready To Move                  Kothanur      2 BHK      NaN
#
#   total_sqft  bath  balcony   price
# 0       1056   2.0      1.0   39.07
# 1       2600   5.0      3.0  120.00
# 2       1440   2.0      3.0   62.00
# 3       1521   3.0      1.0   95.00
# 4       1200   2.0      1.0   51.00

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
# area_type       13320 non-null int64
# availability    13320 non-null object
# location        13319 non-null object
# size            13304 non-null object
# society         7818 non-null object
# total_sqft      13320 non-null object
# bath            13247 non-null float64
# balcony         12711 non-null float64
# price           13320 non-null float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 936.6+ KB

# %% [markdown]
# # handling "size" column

# %%
real_estate["size"].value_counts().plot('barh',figsize=(12,10))
real_estate["size"].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 10 BHK           2
# 11 BHK           2
# 11 Bedroom       2
# 13 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# 14 BHK           1
# 12 Bedroom       1
# 16 BHK           1
# 27 BHK           1
# 43 Bedroom       1
# Name: size, dtype: int64

# %%
real_estate.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
real_estate["size"].fillna('2',inplace=True)

# %%
#real_estate.isnull().sum()
#stemming the the size column and only keeping the numbers

type(real_estate['size'])
real_estate['SIZE']=real_estate['size'].str.split(' ').str[0]
real_estate.drop(['size'],axis=1,inplace=True)

# %%
real_estate["SIZE"]=real_estate["SIZE"].astype(int) # converting the SIZE column to Int
real_estate.info()
# vales abouve 10 seems to be significantely less
# they might be outliyers removing them would help accuracy
def fun(x):
    if x<=10:
        return(x)
    else:
        return(1)
real_estate["SIZE"]=real_estate["SIZE"].apply(lambda x:fun(x))
print(real_estate.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
# area_type       13320 non-null int64
# availability    13320 non-null object
# location        13319 non-null object
# society         7818 non-null object
# total_sqft      13320 non-null object
# bath            13247 non-null float64
# balcony         12711 non-null float64
# price           13320 non-null float64
# SIZE            13320 non-null int32
# dtypes: float64(3), int32(1), int64(1), object(4)
# memory usage: 884.6+ KB
#    area_type   availability                  location  society total_sqft  \
# 0          4         19-Dec  Electronic City Phase II  Coomee        1056
# 1          3  Ready To Move          Chikka Tirupathi  Theanmp       2600
#
#    bath  balcony   price  SIZE
# 0   2.0      1.0   39.07     2
# 1   5.0      3.0  120.00     4

# %%
real_estate.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# SIZE               0
# dtype: int64

# %% [markdown]
# # handling "bath" column

# %%
real_estate["bath"].value_counts().plot('barh',figsize=(12,10))

# %%
real_estate["bath"].fillna(2,inplace=True)

# %%
real_estate.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# society         5502
# total_sqft         0
# bath               0
# balcony          609
# price              0
# SIZE               0
# dtype: int64

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
# area_type       13320 non-null int64
# availability    13320 non-null object
# location        13319 non-null object
# society         7818 non-null object
# total_sqft      13320 non-null object
# bath            13320 non-null float64
# balcony         12711 non-null float64
# price           13320 non-null float64
# SIZE            13320 non-null int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 936.6+ KB

# %% [markdown]
# # cleaning in "balcony" column....

# %%
real_estate["balcony"].value_counts().plot('barh',figsize=(10,7))

# %%
real_estate["balcony"].fillna(1,inplace=True)

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
# area_type       13320 non-null int64
# availability    13320 non-null object
# location        13319 non-null object
# society         7818 non-null object
# total_sqft      13320 non-null object
# bath            13320 non-null float64
# balcony         13320 non-null float64
# price           13320 non-null float64
# SIZE            13320 non-null int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 936.6+ KB

# %%
real_estate.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# society         5502
# total_sqft         0
# bath               0
# balcony            0
# price              0
# SIZE               0
# dtype: int64

# %% [markdown]
# # handling "total sqft"

# %%
hyp=real_estate.loc[real_estate['total_sqft'].str.contains('[-]'),:].copy()
mn=hyp['total_sqft'].str.split(" - ",expand=True).astype(float)
mn['mean']=(mn[0]+mn[1])/2

real_estate.loc[real_estate['total_sqft'].str.contains('-'),'total_sqft']=mn['mean']

#real_estate.loc[real_estate['SIZE']=='0',:]

#real_estate['total_sqft']=real_estate['total_sqft'].astype(str)

# %%
real_estate['total_sqft']=real_estate['total_sqft'].astype(str)

#Converting the Sq. Meter values to Sq. Feet
convert=pd.DataFrame()
convert['meter_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Sq. Meter'),'total_sqft'].copy()
convert['meter_float']=convert['meter_string'].str.replace('Sq. Meter','').astype(float)
convert['meter2_feet']=(convert['meter_float']*10.7639).round(3)

real_estate.loc[real_estate['total_sqft'].str.contains('Meter'),'total_sqft']=convert['meter2_feet']

real_estate['total_sqft']=real_estate['total_sqft'].astype(str)

#--Converting the Sq. Yards values to Sq. Feet
convert2=pd.DataFrame()
convert2['yard_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Yard'),'total_sqft'].copy()
convert2['yard_float']=convert2['yard_string'].str.replace('Sq. Yards','').astype(float)
convert2['yard2_feet']=(convert2['yard_float']*9).round(3)
#house['total_sqft']=house['total_sqft'].astype(str)
convert2['yard2_feet']=convert2['yard_float'].astype(str)
real_estate.loc[real_estate['total_sqft'].str.contains('Yard'),'total_sqft']=convert2['yard2_feet']

#--Converting the Sq. Perch values to Sq. Feet
convert3=pd.DataFrame()
convert3['perch_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Perch'),'total_sqft'].copy()
convert3['perch_float']=convert3['perch_string'].str.replace('Perch','').astype(float)
convert3['perch2_feet']=(convert3['perch_float']*272.25).round(3)
convert3['perch2_feet']=convert3['perch2_feet'].astype(str)
real_estate.loc[real_estate['total_sqft'].str.contains('Perch'),'total_sqft']=convert3['perch2_feet']

#--Converting the Acres values to Sq. Feet
convert4=pd.DataFrame()
convert4['Acre_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Acre'),'total_sqft'].copy()
convert4['Acre_float']=convert4['Acre_string'].str.replace('Acres','').astype(float)
convert4['Acre_feet']=(convert4['Acre_float']*43560).round(3)
convert4['Acre_feet']=convert4['Acre_feet'].astype(str)
real_estate.loc[real_estate['total_sqft'].str.contains('Acres'),'total_sqft']=convert4['Acre_feet']

#--Converting the Guntha values to Sq. Feet
convert5=pd.DataFrame()
convert5['guntha_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Guntha'),'total_sqft'].copy()
convert5['guntha_float']=convert5['guntha_string'].str.replace('Guntha','').astype(float)
convert5['guntha_feet']=(convert5['guntha_float']*1088.98).round(3)
convert5['guntha_feet']=convert5['guntha_feet'].astype(str)
real_estate.loc[real_estate['total_sqft'].str.contains('Guntha'),'total_sqft']=convert5['guntha_feet']

#--Converting the Cent values to Sq. Feet
convert6=pd.DataFrame()
convert6['cent_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Cent'),'total_sqft'].copy()
convert6['cent_float']=convert6['cent_string'].str.replace('Cents','').astype(float)
convert6['cent_feet']=(convert6['cent_float']*435.6).round(3)
convert6['cent_feet']=convert6['cent_feet'].astype(str)
real_estate.loc[real_estate['total_sqft'].str.contains('Cents'),'total_sqft']=convert6['cent_feet']

#--Converting the groud values to Sq. Feet
convert7=pd.DataFrame()
convert7['Grounds_string']=real_estate.loc[real_estate['total_sqft'].str.contains('Grounds'),'total_sqft'].copy()
convert7['Grounds_float']=convert7['Grounds_string'].str.replace('Grounds','').astype(float)
convert7['Grounds_feet']=(convert7['Grounds_float']*2400).round(3)
convert7['Grounds_feet']=convert7['Grounds_feet'].astype(str)
real_estate.loc[real_estate['total_sqft'].str.contains('Grounds'),'total_sqft']=convert7['Grounds_feet']

real_estate['total_sqft'].astype(float)
# Out:
# 0        1056.0
# 1        2600.0
# 2        1440.0
# 3        1521.0
# 4        1200.0
# 5        1170.0
# 6        2732.0
# 7        3300.0
# 8        1310.0
# 9        1020.0
# 10       1800.0
# 11       2785.0
# 12       1000.0
# 13       1100.0
# 14       2250.0
# 15       1175.0
# 16       1180.0
# 17       1540.0
# 18       2770.0
# 19       1100.0
# 20        600.0
# 21       1755.0
# 22       2800.0
# 23       1767.0
# 24        510.0
# 25       1250.0
# 26        660.0
# 27       1610.0
# 28       1151.0
# 29       1025.0
#           ...
# 13290    4050.0
# 13291     812.0
# 13292    1440.0
# 13293    2425.0
# 13294    2200.0
# 13295    1810.0
# 13296    1200.0
# 13297    1060.0
# 13298    1015.0
# 13299    2856.0
# 13300    1500.0
# 13301    1454.0
# 13302    1075.0
# 13303     774.0
# 13304    1187.0
# 13305     500.0
# 13306    1200.0
# 13307    1805.0
# 13308    1527.0
# 13309    1675.0
# 13310    1050.0
# 13311    1500.0
# 13312    1262.0
# 13313    1345.0
# 13314    1715.0
# 13315    3453.0
# 13316    3600.0
# 13317    1141.0
# 13318    4689.0
# 13319     550.0
# Name: total_sqft, Length: 13320, dtype: float64

# %% [markdown]
# # cleaning in "Availability" column....

# %%
real_estate['availability'].unique() #checking unique values
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
plt.figure(figsize=(12,10))
plt.scatter(real_estate['price'], real_estate['availability'])
plt.show()

# %%
#splittting availability column
type(real_estate['availability'])
real_estate['avail']=real_estate['availability'].str.split('-').str[1]

# %%
real_estate.isnull().sum()
# Out:
# area_type           0
# availability        0
# location            1
# society          5502
# total_sqft          0
# bath                0
# balcony             0
# price               0
# SIZE                0
# avail           10597
# dtype: int64

# %%
#replacing na of avail column to ready to move
real_estate['avail'].fillna('Ready to Move',inplace = True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.scatter(real_estate['price'], real_estate['avail'])
plt.show()

# %%
real_estate['avail'].value_counts()
# Out:
# Ready to Move    10597
# Dec                728
# May                338
# Apr                298
# Aug                249
# Mar                246
# Jul                206
# Jun                200
# Jan                126
# Oct                 91
# Sep                 87
# Nov                 79
# Feb                 75
# Name: avail, dtype: int64

# %%
import numpy as np
#converting it to number
real_estate['avail'] = np.where(real_estate['avail']=='Ready to Move', 1, 0)

# %%
real_estate.head(10)
# Out:
#    area_type   availability                  location  society total_sqft  \
# 0          4         19-Dec  Electronic City Phase II  Coomee        1056
# 1          3  Ready To Move          Chikka Tirupathi  Theanmp       2600
# 2          2  Ready To Move               Uttarahalli      NaN       1440
# 3          4  Ready To Move        Lingadheeranahalli  Soiewre       1521
# 4          4  Ready To Move                  Kothanur      NaN       1200
# 5          4  Ready To Move                Whitefield  DuenaTa       1170
# 6          4         18-May          Old Airport Road  Jaades        2732
# 7          4  Ready To Move              Rajaji Nagar  Brway G       3300
# 8          4  Ready To Move              Marathahalli      NaN       1310
# 9          3  Ready To Move              Gandhi Bazar      NaN       1020
#
#    bath  balcony   price  SIZE  avail
# 0   2.0      1.0   39.07     2      0
# 1   5.0      3.0  120.00     4      1
# 2   2.0      3.0   62.00     3      1
# 3   3.0      1.0   95.00     3      1
# 4   2.0      1.0   51.00     2      1
# 5   2.0      1.0   38.00     2      1
# 6   4.0      1.0  204.00     4      0
# 7   4.0      1.0  600.00     4      1
# 8   3.0      1.0   63.25     3      1
# 9   6.0      1.0  370.00     6      1

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 10 columns):
# area_type       13320 non-null int64
# availability    13320 non-null object
# location        13319 non-null object
# society         7818 non-null object
# total_sqft      13320 non-null object
# bath            13320 non-null float64
# balcony         13320 non-null float64
# price           13320 non-null float64
# SIZE            13320 non-null int64
# avail           13320 non-null int32
# dtypes: float64(3), int32(1), int64(2), object(4)
# memory usage: 988.7+ KB

# %%
real_estate['total_sqft']=real_estate['total_sqft'].astype(float)

# %% [markdown]
# # handling "society" column

# %%
real_estate.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# society         5502
# total_sqft         0
# bath               0
# balcony            0
# price              0
# SIZE               0
# avail              0
# dtype: int64

# %%
real_estate.shape
# Out:
# (13320, 10)

# %%
5499/13320
# Out:
# 0.41283783783783784

# %% [markdown]
# missing value of society is 41%...which is near about 50%....so we dropped the "society" column

# %%
#dropping na values
real_estate.drop(['society'],inplace=True,axis=1)

# %%
real_estate
# Out:
#        area_type   availability                  location  total_sqft  bath  \
# 0              4         19-Dec  Electronic City Phase II      1056.0   2.0
# 1              3  Ready To Move          Chikka Tirupathi      2600.0   5.0
# 2              2  Ready To Move               Uttarahalli      1440.0   2.0
# 3              4  Ready To Move        Lingadheeranahalli      1521.0   3.0
# 4              4  Ready To Move                  Kothanur      1200.0   2.0
# 5              4  Ready To Move                Whitefield      1170.0   2.0
# 6              4         18-May          Old Airport Road      2732.0   4.0
# 7              4  Ready To Move              Rajaji Nagar      3300.0   4.0
# 8              4  Ready To Move              Marathahalli      1310.0   3.0
# 9              3  Ready To Move              Gandhi Bazar      1020.0   6.0
# 10             4         18-Feb                Whitefield      1800.0   2.0
# 11             3  Ready To Move                Whitefield      2785.0   5.0
# 12             4  Ready To Move        7th Phase JP Nagar      1000.0   2.0
# 13             2  Ready To Move                 Gottigere      1100.0   2.0
# 14             3  Ready To Move                  Sarjapur      2250.0   3.0
# 15             4  Ready To Move               Mysore Road      1175.0   2.0
# 16             4  Ready To Move             Bisuvanahalli      1180.0   3.0
# 17             4  Ready To Move     Raja Rajeshwari Nagar      1540.0   3.0
# 18             4  Ready To Move     Ramakrishnappa Layout      2770.0   4.0
# 19             4  Ready To Move        Manayata Tech Park      1100.0   2.0
# 20             2  Ready To Move                   Kengeri       600.0   1.0
# 21             4         19-Dec                Binny Pete      1755.0   3.0
# 22             3  Ready To Move               Thanisandra      2800.0   5.0
# 23             4  Ready To Move                 Bellandur      1767.0   3.0
# 24             4         18-Nov               Thanisandra       510.0   1.0
# 25             4         18-May           Mangammanapalya      1250.0   3.0
# 26             4  Ready To Move           Electronic City       660.0   1.0
# 27             2         20-Dec                Whitefield      1610.0   3.0
# 28             4         17-Oct          Ramagondanahalli      1151.0   2.0
# 29             4  Ready To Move           Electronic City      1025.0   2.0
# ...          ...            ...                       ...         ...   ...
# 13290          4  Ready To Move            Sarjapur  Road      4050.0   2.0
# 13291          3         18-Jan            Weavers Colony       812.0   1.0
# 13292          4         18-Jul          Udayapur Village      1440.0   2.0
# 13293          4  Ready To Move            Sarjapur  Road      2425.0   5.0
# 13294          4  Ready To Move             Sultan Palaya      2200.0   3.0
# 13295          4         18-Feb              Haralur Road      1810.0   3.0
# 13296          4  Ready To Move                  Cox Town      1200.0   2.0
# 13297          4  Ready To Move           Electronic City      1060.0   2.0
# 13298          4  Ready To Move             Kenchenahalli      1015.0   2.0
# 13299          4         18-Dec                Whitefield      2856.0   5.0
# 13300          3  Ready To Move             Hosakerehalli      1500.0   6.0
# 13301          4  Ready To Move                  Kothanur      1454.0   3.0
# 13302          4  Ready To Move      Annaiah Reddy Layout      1075.0   2.0
# 13303          3  Ready To Move            Vidyaranyapura       774.0   5.0
# 13304          4  Ready To Move     Raja Rajeshwari Nagar      1187.0   2.0
# 13305          1  Ready To Move                  Hulimavu       500.0   1.0
# 13306          3  Ready To Move     Rajarajeshwari Nagara      1200.0   5.0
# 13307          2  Ready To Move              Billekahalli      1805.0   3.0
# 13308          2  Ready To Move         Bannerghatta Road      1527.0   3.0
# 13309          4  Ready To Move              Yeshwanthpur      1675.0   3.0
# 13310          4  Ready To Move              Rachenahalli      1050.0   2.0
# 13311          3  Ready To Move          Ramamurthy Nagar      1500.0   9.0
# 13312          4  Ready To Move                 Bellandur      1262.0   2.0
# 13313          4  Ready To Move               Uttarahalli      1345.0   2.0
# 13314          4  Ready To Move         Green Glen Layout      1715.0   3.0
# 13315          2  Ready To Move                Whitefield      3453.0   4.0
# 13316          4  Ready To Move             Richards Town      3600.0   5.0
# 13317          2  Ready To Move     Raja Rajeshwari Nagar      1141.0   2.0
# 13318          4         18-Jun           Padmanabhanagar      4689.0   4.0
# 13319          4  Ready To Move              Doddathoguru       550.0   1.0
#
#        balcony   price  SIZE  avail
# 0          1.0   39.07     2      0
# 1          3.0  120.00     4      1
# 2          3.0   62.00     3      1
# 3          1.0   95.00     3      1
# 4          1.0   51.00     2      1
# 5          1.0   38.00     2      1
# 6          1.0  204.00     4      0
# 7          1.0  600.00     4      1
# 8          1.0   63.25     3      1
# 9          1.0  370.00     6      1
# 10         2.0   70.00     3      0
# 11         3.0  295.00     4      1
# 12         1.0   38.00     2      1
# 13         2.0   40.00     2      1
# 14         2.0  148.00     3      1
# 15         2.0   73.50     2      1
# 16         2.0   48.00     3      1
# 17         3.0   60.00     3      1
# 18         2.0  290.00     3      1
# 19         2.0   48.00     2      1
# 20         1.0   15.00     1      1
# 21         1.0  122.00     3      0
# 22         2.0  380.00     4      1
# 23         1.0  103.00     3      1
# 24         0.0   25.25     1      0
# 25         2.0   56.00     3      0
# 26         1.0   23.10     2      1
# 27         2.0   81.00     3      0
# 28         2.0   48.77     2      0
# 29         1.0   47.00     3      1
# ...        ...     ...   ...    ...
# 13290      1.0  450.00     4      1
# 13291      0.0   26.00     1      0
# 13292      2.0   63.93     3      0
# 13293      1.0  195.00     4      1
# 13294      3.0   80.00     4      1
# 13295      2.0  112.00     3      0
# 13296      2.0  140.00     2      1
# 13297      1.0   52.00     2      1
# 13298      2.0   60.00     2      1
# 13299      0.0  154.50     4      0
# 13300      2.0  145.00     5      1
# 13301      3.0   71.50     3      1
# 13302      2.0   48.00     2      1
# 13303      3.0   70.00     5      1
# 13304      2.0   40.14     2      1
# 13305      3.0  220.00     1      1
# 13306      1.0  325.00     4      1
# 13307      3.0  134.00     3      1
# 13308      1.0  142.00     3      1
# 13309      1.0   92.13     3      1
# 13310      2.0   52.71     2      1
# 13311      2.0  250.00     7      1
# 13312      2.0   47.00     2      1
# 13313      1.0   57.00     3      1
# 13314      3.0  112.00     3      1
# 13315      0.0  231.00     5      1
# 13316      1.0  400.00     4      1
# 13317      1.0   60.00     2      1
# 13318      1.0  488.00     4      0
# 13319      1.0   17.00     1      1
#
# [13320 rows x 9 columns]

# %%
real_estate.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        1
# total_sqft      0
# bath            0
# balcony         0
# price           0
# SIZE            0
# avail           0
# dtype: int64

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
# area_type       13320 non-null int64
# availability    13320 non-null object
# location        13319 non-null object
# total_sqft      13320 non-null float64
# bath            13320 non-null float64
# balcony         13320 non-null float64
# price           13320 non-null float64
# SIZE            13320 non-null int64
# avail           13320 non-null int32
# dtypes: float64(4), int32(1), int64(2), object(2)
# memory usage: 884.6+ KB

# %%
real_estate.drop(["availability"],inplace=True,axis=1)

# %%
real_estate
# Out:
#        area_type                  location  total_sqft  bath  balcony   price  \
# 0              4  Electronic City Phase II      1056.0   2.0      1.0   39.07
# 1              3          Chikka Tirupathi      2600.0   5.0      3.0  120.00
# 2              2               Uttarahalli      1440.0   2.0      3.0   62.00
# 3              4        Lingadheeranahalli      1521.0   3.0      1.0   95.00
# 4              4                  Kothanur      1200.0   2.0      1.0   51.00
# 5              4                Whitefield      1170.0   2.0      1.0   38.00
# 6              4          Old Airport Road      2732.0   4.0      1.0  204.00
# 7              4              Rajaji Nagar      3300.0   4.0      1.0  600.00
# 8              4              Marathahalli      1310.0   3.0      1.0   63.25
# 9              3              Gandhi Bazar      1020.0   6.0      1.0  370.00
# 10             4                Whitefield      1800.0   2.0      2.0   70.00
# 11             3                Whitefield      2785.0   5.0      3.0  295.00
# 12             4        7th Phase JP Nagar      1000.0   2.0      1.0   38.00
# 13             2                 Gottigere      1100.0   2.0      2.0   40.00
# 14             3                  Sarjapur      2250.0   3.0      2.0  148.00
# 15             4               Mysore Road      1175.0   2.0      2.0   73.50
# 16             4             Bisuvanahalli      1180.0   3.0      2.0   48.00
# 17             4     Raja Rajeshwari Nagar      1540.0   3.0      3.0   60.00
# 18             4     Ramakrishnappa Layout      2770.0   4.0      2.0  290.00
# 19             4        Manayata Tech Park      1100.0   2.0      2.0   48.00
# 20             2                   Kengeri       600.0   1.0      1.0   15.00
# 21             4                Binny Pete      1755.0   3.0      1.0  122.00
# 22             3               Thanisandra      2800.0   5.0      2.0  380.00
# 23             4                 Bellandur      1767.0   3.0      1.0  103.00
# 24             4               Thanisandra       510.0   1.0      0.0   25.25
# 25             4           Mangammanapalya      1250.0   3.0      2.0   56.00
# 26             4           Electronic City       660.0   1.0      1.0   23.10
# 27             2                Whitefield      1610.0   3.0      2.0   81.00
# 28             4          Ramagondanahalli      1151.0   2.0      2.0   48.77
# 29             4           Electronic City      1025.0   2.0      1.0   47.00
# ...          ...                       ...         ...   ...      ...     ...
# 13290          4            Sarjapur  Road      4050.0   2.0      1.0  450.00
# 13291          3            Weavers Colony       812.0   1.0      0.0   26.00
# 13292          4          Udayapur Village      1440.0   2.0      2.0   63.93
# 13293          4            Sarjapur  Road      2425.0   5.0      1.0  195.00
# 13294          4             Sultan Palaya      2200.0   3.0      3.0   80.00
# 13295          4              Haralur Road      1810.0   3.0      2.0  112.00
# 13296          4                  Cox Town      1200.0   2.0      2.0  140.00
# 13297          4           Electronic City      1060.0   2.0      1.0   52.00
# 13298          4             Kenchenahalli      1015.0   2.0      2.0   60.00
# 13299          4                Whitefield      2856.0   5.0      0.0  154.50
# 13300          3             Hosakerehalli      1500.0   6.0      2.0  145.00
# 13301          4                  Kothanur      1454.0   3.0      3.0   71.50
# 13302          4      Annaiah Reddy Layout      1075.0   2.0      2.0   48.00
# 13303          3            Vidyaranyapura       774.0   5.0      3.0   70.00
# 13304          4     Raja Rajeshwari Nagar      1187.0   2.0      2.0   40.14
# 13305          1                  Hulimavu       500.0   1.0      3.0  220.00
# 13306          3     Rajarajeshwari Nagara      1200.0   5.0      1.0  325.00
# 13307          2              Billekahalli      1805.0   3.0      3.0  134.00
# 13308          2         Bannerghatta Road      1527.0   3.0      1.0  142.00
# 13309          4              Yeshwanthpur      1675.0   3.0      1.0   92.13
# 13310          4              Rachenahalli      1050.0   2.0      2.0   52.71
# 13311          3          Ramamurthy Nagar      1500.0   9.0      2.0  250.00
# 13312          4                 Bellandur      1262.0   2.0      2.0   47.00
# 13313          4               Uttarahalli      1345.0   2.0      1.0   57.00
# 13314          4         Green Glen Layout      1715.0   3.0      3.0  112.00
# 13315          2                Whitefield      3453.0   4.0      0.0  231.00
# 13316          4             Richards Town      3600.0   5.0      1.0  400.00
# 13317          2     Raja Rajeshwari Nagar      1141.0   2.0      1.0   60.00
# 13318          4           Padmanabhanagar      4689.0   4.0      1.0  488.00
# 13319          4              Doddathoguru       550.0   1.0      1.0   17.00
#
#        SIZE  avail
# 0         2      0
# 1         4      1
# 2         3      1
# 3         3      1
# 4         2      1
# 5         2      1
# 6         4      0
# 7         4      1
# 8         3      1
# 9         6      1
# 10        3      0
# 11        4      1
# 12        2      1
# 13        2      1
# 14        3      1
# 15        2      1
# 16        3      1
# 17        3      1
# 18        3      1
# 19        2      1
# 20        1      1
# 21        3      0
# 22        4      1
# 23        3      1
# 24        1      0
# 25        3      0
# 26        2      1
# 27        3      0
# 28        2      0
# 29        3      1
# ...     ...    ...
# 13290     4      1
# 13291     1      0
# 13292     3      0
# 13293     4      1
# 13294     4      1
# 13295     3      0
# 13296     2      1
# 13297     2      1
# 13298     2      1
# 13299     4      0
# 13300     5      1
# 13301     3      1
# 13302     2      1
# 13303     5      1
# 13304     2      1
# 13305     1      1
# 13306     4      1
# 13307     3      1
# 13308     3      1
# 13309     3      1
# 13310     2      1
# 13311     7      1
# 13312     2      1
# 13313     3      1
# 13314     3      1
# 13315     5      1
# 13316     4      1
# 13317     2      1
# 13318     4      0
# 13319     1      1
#
# [13320 rows x 8 columns]

# %%
real_estate['area_type'].astype(float)
# Out:
# 0        4.0
# 1        3.0
# 2        2.0
# 3        4.0
# 4        4.0
# 5        4.0
# 6        4.0
# 7        4.0
# 8        4.0
# 9        3.0
# 10       4.0
# 11       3.0
# 12       4.0
# 13       2.0
# 14       3.0
# 15       4.0
# 16       4.0
# 17       4.0
# 18       4.0
# 19       4.0
# 20       2.0
# 21       4.0
# 22       3.0
# 23       4.0
# 24       4.0
# 25       4.0
# 26       4.0
# 27       2.0
# 28       4.0
# 29       4.0
#         ...
# 13290    4.0
# 13291    3.0
# 13292    4.0
# 13293    4.0
# 13294    4.0
# 13295    4.0
# 13296    4.0
# 13297    4.0
# 13298    4.0
# 13299    4.0
# 13300    3.0
# 13301    4.0
# 13302    4.0
# 13303    3.0
# 13304    4.0
# 13305    1.0
# 13306    3.0
# 13307    2.0
# 13308    2.0
# 13309    4.0
# 13310    4.0
# 13311    3.0
# 13312    4.0
# 13313    4.0
# 13314    4.0
# 13315    2.0
# 13316    4.0
# 13317    2.0
# 13318    4.0
# 13319    4.0
# Name: area_type, Length: 13320, dtype: float64

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 8 columns):
# area_type     13320 non-null int64
# location      13319 non-null object
# total_sqft    13320 non-null float64
# bath          13320 non-null float64
# balcony       13320 non-null float64
# price         13320 non-null float64
# SIZE          13320 non-null int64
# avail         13320 non-null int32
# dtypes: float64(4), int32(1), int64(2), object(1)
# memory usage: 780.5+ KB

# %% [markdown]
# # Handling "Location" column...

# %%
real_estate.dropna(inplace=True)

real_estate.head()
# Out:
#    area_type                  location  total_sqft  bath  balcony   price  \
# 0          4  Electronic City Phase II      1056.0   2.0      1.0   39.07
# 1          3          Chikka Tirupathi      2600.0   5.0      3.0  120.00
# 2          2               Uttarahalli      1440.0   2.0      3.0   62.00
# 3          4        Lingadheeranahalli      1521.0   3.0      1.0   95.00
# 4          4                  Kothanur      1200.0   2.0      1.0   51.00
#
#    SIZE  avail
# 0     2      0
# 1     4      1
# 2     3      1
# 3     3      1
# 4     2      1

# %%
# using label encoder
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
real_estate["location"]=encode.fit_transform(real_estate["location"])

# %%
real_estate.head()
# Out:
#    area_type  location  total_sqft  bath  balcony   price  SIZE  avail
# 0          4       419      1056.0   2.0      1.0   39.07     2      0
# 1          3       317      2600.0   5.0      3.0  120.00     4      1
# 2          2      1179      1440.0   2.0      3.0   62.00     3      1
# 3          4       757      1521.0   3.0      1.0   95.00     3      1
# 4          4       716      1200.0   2.0      1.0   51.00     2      1

# %%
#real_estate.info()
#real_estate.to_csv("C:/Users/vish/Desktop/dataset.csv")

# %%
real_estate=real_estate.astype(float)

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13319 entries, 0 to 13319
# Data columns (total 8 columns):
# area_type     13319 non-null float64
# location      13319 non-null float64
# total_sqft    13319 non-null float64
# bath          13319 non-null float64
# balcony       13319 non-null float64
# price         13319 non-null float64
# SIZE          13319 non-null float64
# avail         13319 non-null float64
# dtypes: float64(8)
# memory usage: 936.5 KB

# %%
# export for visualization
#real_estate.to_csv("C:/Users/vish/Desktop/viz.csv")

# %%
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import re

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
sns.set(font_scale=1)

# %%
#standardizing data
saleprice_scaled = StandardScaler().fit_transform(real_estate['price'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-0.70194252]
#  [-0.69898883]
#  [-0.69522958]
#  [-0.68851664]
#  [-0.68851664]
#  [-0.68851664]
#  [-0.68851664]
#  [-0.68851664]
#  [-0.68851664]
#  [-0.68683841]]
#
# outer range (high) of the distribution:
# [[14.01281655]
#  [14.34846342]
#  [14.9526278 ]
#  [16.69799156]
#  [16.69799156]
#  [17.36928531]
#  [17.61095106]
#  [18.04057906]
#  [18.79242807]
#  [23.41092909]]

# %%
#histogram and normal probability plot
sns.distplot(real_estate['price'], fit=norm);
fig = plt.figure()
res = stats.probplot(real_estate['price'], plot=plt)

# %%
#applying log transformation
real_estate['price'] = np.log(real_estate['price'])

# %%
#transformed histogram and normal probability plot
sns.distplot(real_estate['price'], fit=norm);
fig = plt.figure()
res = stats.probplot(real_estate['price'], plot=plt)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
sns.distplot(real_estate[real_estate['price'] < 500]['price'], kde=True, ax=ax, bins=500, fit=stats.norm)
ax.set(title= 'distribution of price < 500 lakhs(INR)', xlabel='price in lakhs', ylabel='probability')
ax.axvline(real_estate['price'].mean(), color='r', linestyle='--')
ax.axvline(real_estate['price'].median(), color='g', linestyle='-')
ax.axvline(real_estate['price'].mode().get_values()[0], color='y', linestyle='-')
plt.legend({'Normal distribution': stats.norm, 'Mean':real_estate['price'].mean(),'Median':real_estate['price'].median(), 'Mode': real_estate['price'].mode().get_values()[0]})
plt.show()

# %% [markdown]
# # Using ml algorithm

# %%
x=real_estate.price     # taking only labels
y=real_estate.drop(['price'],axis=1)  # taking only attributes

# %%
# spliting data into test and train sets
from sklearn.model_selection import train_test_split
train_labels,test_labels,train_data,test_data=train_test_split(x,y,test_size=.25,random_state=10)

# %%
test_data
# Out:
#        area_type  location  total_sqft  bath  balcony  SIZE  avail
# 6768         4.0    1039.0      1320.0   2.0      2.0   2.0    1.0
# 507          4.0     575.0      1000.0   2.0      1.0   2.0    1.0
# 9039         4.0     506.0      1194.0   2.0      2.0   2.0    1.0
# 11422        4.0    1148.0      1732.0   3.0      1.0   3.0    0.0
# 11547        2.0     230.0      2700.0   3.0      0.0   4.0    1.0
# 2393         4.0    1084.0      1100.0   2.0      1.0   2.0    1.0
# 11962        2.0     972.0      1021.0   3.0      2.0   3.0    1.0
# 6209         4.0    1025.0      1914.0   3.0      2.0   3.0    1.0
# 2119         4.0      72.0      1405.0   2.0      2.0   3.0    1.0
# 6046         4.0     509.0      1459.0   3.0      2.0   3.0    1.0
# 2791         4.0     837.0      1525.0   3.0      2.0   3.0    1.0
# 7229         4.0     664.0      1591.0   3.0      1.0   3.0    0.0
# 3903         4.0      55.0       900.0   2.0      1.0   2.0    1.0
# 8531         4.0    1191.0      1033.0   2.0      2.0   2.0    0.0
# 10187        4.0     972.0       945.0   2.0      1.0   2.0    1.0
# 7856         4.0     208.0       870.0   2.0      2.0   2.0    1.0
# 76           4.0     641.0      1150.0   2.0      3.0   2.0    1.0
# 1991         4.0     745.0      1172.0   2.0      2.0   2.0    1.0
# 8709         4.0     536.0      1726.0   3.0      2.0   3.0    0.0
# 12988        2.0     419.0       545.0   1.0      1.0   2.0    1.0
# 4626         3.0     453.0      1350.0   3.0      0.0   3.0    1.0
# 2347         4.0     861.0      1200.0   2.0      2.0   2.0    1.0
# 2650         4.0      62.0      1400.0   2.0      1.0   3.0    1.0
# 8909         3.0    1028.0      2100.0   3.0      0.0   3.0    1.0
# 11782        4.0     716.0      1787.0   3.0      2.0   3.0    1.0
# 6292         3.0      83.0      1200.0   4.0      2.0   3.0    1.0
# 7320         3.0      44.0      1200.0   3.0      1.0   3.0    1.0
# 7699         3.0     880.0      1500.0   3.0      2.0   3.0    0.0
# 11813        4.0      68.0      3000.0   3.0      2.0   3.0    1.0
# 10932        4.0     188.0       645.0   1.0      1.0   1.0    0.0
# ...          ...       ...         ...   ...      ...   ...    ...
# 10144        4.0     110.0      1921.0   4.0      3.0   3.0    1.0
# 5276         4.0     639.0       849.0   2.0      1.0   2.0    0.0
# 3597         4.0    1179.0      1310.0   2.0      1.0   3.0    1.0
# 8855         4.0     306.0      1123.0   2.0      1.0   2.0    1.0
# 1123         3.0     464.0      1500.0   3.0      2.0   3.0    0.0
# 11271        4.0     268.0       845.0   2.0      2.0   2.0    1.0
# 11042        4.0     278.0      1590.0   3.0      0.0   3.0    0.0
# 8690         2.0    1252.0      1558.0   3.0      2.0   3.0    0.0
# 5455         4.0    1264.0      1260.0   2.0      2.0   2.0    1.0
# 1110         4.0     530.0      1639.0   3.0      2.0   3.0    0.0
# 5554         4.0     554.0      1310.0   2.0      3.0   3.0    1.0
# 6373         4.0    1252.0       750.0   1.0      1.0   1.0    0.0
# 10274        2.0     530.0      1350.0   3.0      2.0   3.0    1.0
# 4430         2.0     740.0       780.0   2.0      1.0   2.0    1.0
# 252          4.0      72.0      1270.0   2.0      2.0   2.0    1.0
# 368          2.0     626.0       930.0   2.0      2.0   2.0    1.0
# 5970         3.0     837.0        45.0   1.0      0.0   1.0    1.0
# 4932         3.0     194.0       500.0   5.0      2.0   5.0    1.0
# 11168        4.0    1141.0      1062.0   2.0      1.0   2.0    1.0
# 6774         4.0     539.0      1596.0   3.0      3.0   3.0    1.0
# 5927         4.0     575.0      1100.0   2.0      1.0   2.0    1.0
# 10957        4.0     907.0      1100.0   2.0      1.0   2.0    1.0
# 11145        2.0    1138.0      2000.0   3.0      1.0   3.0    1.0
# 7600         4.0     799.0      4000.0   4.0      1.0   4.0    1.0
# 5896         4.0    1179.0      1380.0   2.0      1.0   2.0    1.0
# 7718         2.0    1039.0      3385.5   6.0      0.0   4.0    1.0
# 13260        2.0     428.0      1420.0   2.0      0.0   2.0    1.0
# 8118         4.0    1038.0      1175.0   2.0      2.0   2.0    1.0
# 10020        4.0      98.0      1896.0   3.0      2.0   3.0    1.0
# 12561        4.0     232.0      1215.0   2.0      1.0   2.0    1.0
#
# [3330 rows x 7 columns]

# %%
#using linear model
import sklearn as model
from sklearn import linear_model

# %%
lm=linear_model.LinearRegression()
model_linear=lm.fit(train_data,train_labels)

# %%
P1=model_linear.predict(test_data)

# %%
# checking for error and accuracy of the model
import numpy as np
from sklearn import metrics

# %%
# using random forest algo
from sklearn.ensemble import RandomForestRegressor 

rf = RandomForestRegressor(n_estimators = 500, random_state = 7)
model_rand=rf.fit(train_data,train_labels)
# Out:
# D:\Users\akash\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
P2=model_rand.predict(test_data)

# %%
print(np.sqrt(metrics.mean_squared_error(test_labels,P2)))
print(np.sqrt(metrics.r2_score(test_labels,P2)))
print(np.sqrt(metrics.mean_absolute_error(test_labels,P2)))
# Out:
# 85.37433692612488
# 0.7279782233452705
# 5.719877413731776

# %%
#using gradent boost
from sklearn.ensemble import gradient_boosting
gb=gradient_boosting.GradientBoostingRegressor(n_estimators=49,random_state = 7)
model_gradent=gb.fit(train_data,train_labels)

# %%
P3=model_gradent.predict(test_data)

# %%
print(np.sqrt(metrics.mean_squared_error(test_labels,P3)))
print(np.sqrt(metrics.r2_score(test_labels,P3)))
print(np.sqrt(metrics.mean_absolute_error(test_labels,P3)))
# Out:
# 82.45327248439713
# 0.749377870325801
# 6.0171158637684785

# %%
tempdata=pd.Series(P3)

tempdata2=pd.DataFrame(tempdata,test_labels)
#tempdata.to_csv("predection.csv")
#test_labels.to_csv("lablels.csv")
tempdata2.to_csv("viz.csv")

# %%
#using svm algo
from sklearn import svm
svm=svm.SVR(gamma='auto')
model_svm=svm.fit(train_data,train_labels)

# %%
P4=model_svm.predict(test_data)

# %%
print(np.sqrt(metrics.mean_squared_error(test_labels,P4)))

print(np.sqrt(metrics.mean_absolute_error(test_labels,P4)))
# Out:
# 129.48316274318103
# 7.653517875923065

# %% [markdown]
# #  creating and testing the pickle file

# %%
# using gradent boost since it has least R2
import pickle
pickle.dump(model_gradent, open("C:/Users/akash/Desktop/gb.pkl", 'wb'))
pickle.dump(model_rand, open("C:/Users/akash/Desktop/rf.pkl", 'wb'))

# %%
loaded_model = pickle.load(open("C:/Users/akash/Desktop/gb.pkl", 'rb'))

# %%
mm=loaded_model.predict(test_data)

# %%
print(np.sqrt(metrics.mean_squared_error(test_labels,mm)))
# Out:
# 82.45327248439713

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3330 entries, 6768 to 12561
# Data columns (total 7 columns):
# area_type     3330 non-null float64
# location      3330 non-null float64
# total_sqft    3330 non-null float64
# bath          3330 non-null float64
# balcony       3330 non-null float64
# SIZE          3330 non-null float64
# avail         3330 non-null float64
# dtypes: float64(7)
# memory usage: 208.1 KB
